# %%
import sys
sys.path.append('/Users/fabioballoni/Development/repos/risk/risk_pylibrary/')
from risk_models import pnl_fifo_daily_reset as _fifo
from risk_models import pnl_support_daily_reset as _pnl_sup
from tools.snowflake_db import db_connection as db
import openpyxl

# %%
qry='''
SELECT
    REPORT_DATE,
    SEC_ACC_NO,
    DATA_SRC_PRIMARY,
    SUM(RPNL) AS RPNL,
FROM TEAMS_PRD.RISK_FUNCTION_SOURCE.SRC_CURR__RISK_FUNCTION__MRM_TRADING_BOOK_PNL
WHERE 
    SEC_ACC_NO = 9800001601
    AND REPORT_DATE >= '2026-04-01'
    AND DATA_SRC_PRIMARY = 'inquisitor_daily_reset'
GROUP BY
    REPORT_DATE,
    SEC_ACC_NO,
    DATA_SRC_PRIMARY;
'''

# %%
df = db.run_query(query=qry)
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# ...

# %%
df.head()
# Out:
#           report_date  sec_acc_no        data_src_primary          rpnl
# 0 2026-04-28 23:59:59  9800001601  inquisitor_daily_reset  25751.625327
# 1 2026-04-07 23:59:59  9800001601  inquisitor_daily_reset  45110.020965
# 2 2026-04-14 23:59:59  9800001601  inquisitor_daily_reset   3218.278648
# 3 2026-04-01 23:59:59  9800001601  inquisitor_daily_reset -48035.239302
# 4 2026-04-29 23:59:59  9800001601  inquisitor_daily_reset   3157.119822
